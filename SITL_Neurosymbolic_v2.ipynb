# %% [markdown]
# <a href="https://colab.research.google.com/github/vaasssuuu/SITL_Neurosymbolic_KG/blob/main/SITL_Neurosymbolic_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# CELL 1: ENVIRONMENT SETUP & SERVER BOOT
# ==========================================
print("1. Installing Python libraries...")
# !pip install -q langchain langchain-community neo4j

import subprocess
import time
import urllib.request
from urllib.error import URLError
import os
import json
import re
import atexit

print("2. Installing zstd...")
# !apt-get install zstd -y > /dev/null 2>&1

print("3. Installing Ollama...")
# !curl -fsSL https://ollama.com/install.sh | sh > /dev/null 2>&1

print("4. Booting Ollama server in the background...")
process = subprocess.Popen(['ollama', 'serve'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
time.sleep(5)

try:
    urllib.request.urlopen('http://localhost:11434/')
    print("✅ Ollama server is running!")
except URLError as e:
    print(f"❌ Ollama server failed to start: {e}")

print("5. Pulling Llama 3 model (this takes a minute)...")
# !ollama pull llama3 > /dev/null 2>&1
print("✅ Model ready!")
# Out:
# 1. Installing Python libraries...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# 2. Installing zstd...
# 3. Installing Ollama...
# 4. Booting Ollama server in the background...
# ✅ Ollama server is running!
# 5. Pulling Llama 3 model (this takes a minute)...
# ✅ Model ready!

# %%
# ==========================================
# CELL 2: DATABASE & MODEL INITIALIZATION
# ==========================================
from google.colab import userdata
from neo4j import GraphDatabase
from langchain_community.chat_models import ChatOllama
from langchain_core.prompts import PromptTemplate

# Secure connection using Colab Secrets 🔑
NEO4J_URI = userdata.get('NEO4J_URI')
NEO4J_USERNAME = userdata.get('NEO4J_USERNAME')
NEO4J_PASSWORD = userdata.get('NEO4J_PASSWORD')

if not NEO4J_URI or not NEO4J_PASSWORD:
    raise ValueError("⚠️ Missing Credentials: Go to the Colab Secrets 🔑 menu and add your Neo4j keys!")

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
atexit.register(driver.close)
print("✅ Connected to Neo4j AuraDB!")

# Initialize Models (with 512 token limit for flawless JSON extraction)
llm_chat = ChatOllama(model="llama3", temperature=0, num_predict=512, keep_alive=-1, timeout=300)
llm_extractor = ChatOllama(model="llama3", temperature=0, format="json", num_predict=512, keep_alive=-1, timeout=300)
llm_router = ChatOllama(model="llama3", temperature=0, format="json", num_predict=32, keep_alive=-1, timeout=300)
print("✅ Neural Engines Initialized!")
# Out:
# ✅ Connected to Neo4j AuraDB!
# ✅ Neural Engines Initialized!
# /tmp/ipykernel_13808/1922897677.py:22: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm_chat = ChatOllama(model="llama3", temperature=0, num_predict=512, keep_alive=-1, timeout=300)

# %%
# ==========================================
# CELL 3: PROMPTS & KNOWLEDGE GRAPH LOGIC
# ==========================================
router_prompt = PromptTemplate.from_template(
    """Analyze the user question and classify its intent into exactly ONE category:
    1. "FACT_CHECK": Specific factual questions about blockchain/crypto.
    2. "DISCOVERY": Broad questions SPECIFICALLY about blockchain/crypto.
    3. "OUT_OF_DOMAIN": Completely unrelated to blockchain or crypto.
    Return ONLY a JSON object with a single key "intent".
    Question: {question}"""
)

generate_prompt = PromptTemplate.from_template(
    """You are an expert in Blockchain technology. Answer the following question concisely based ONLY on verified knowledge: {question}

    If the question asks about something that did NOT happen, or asks about concepts that do not exist in your verified knowledge, simply state: "The verified knowledge graph does not contain information to support that claim." Then, optionally provide a relevant verified fact.

    {feedback}"""
)

extract_prompt = PromptTemplate.from_template(
    """You are a strict factual extractor.
    User's Original Question: {question}
    Draft Response: {draft_response}

    CRITICAL RULES:
    1. If the text states "The verified knowledge graph does not contain...", you MUST return an empty array: []
    2. Extract ONLY the core factual triples answering the question. Ignore fluff.
    3. PRESERVE NEGATIONS: If the text says "X is not Y", the predicate MUST be "is not".

    EXAMPLES:
    Text: "No, Ethereum is not a centralized database." -> [{{"subject": "Ethereum", "predicate": "is not", "object": "centralized database"}}]
    Text: "Proof of Stake uses validators." -> [{{"subject": "Proof of Stake", "predicate": "uses", "object": "validators"}}]

    Format STRICTLY as a JSON list of dictionaries with keys 'subject', 'predicate', 'object'.
    """
)

def classify_intent(question):
    try:
        return json.loads((router_prompt | llm_router).invoke({"question": question}).content).get("intent", "DISCOVERY")
    except:
        return "DISCOVERY"

def check_entity_exists(tx, entity_name):
    query = "MATCH (n) WHERE toLower(n.name) CONTAINS toLower($name) OR toLower($name) CONTAINS toLower(n.name) RETURN count(n) > 0 AS exists"
    return tx.run(query, name=entity_name).single()["exists"]

def validate_triple_in_neo4j(tx, subject, predicate, obj):
    query = """MATCH (s)-[p]-(o)
               WHERE (toLower(s.name) CONTAINS toLower($subject) OR toLower($subject) CONTAINS toLower(s.name))
               AND (toLower(o.name) CONTAINS toLower($object) OR toLower($object) CONTAINS toLower(o.name))
               RETURN count(p) > 0 AS is_valid"""
    record = tx.run(query, subject=subject, object=obj).single()
    return record["is_valid"] if record else False

# %%
# ==========================================
# CELL 4: THE NEURO-SYMBOLIC PIPELINE
# ==========================================
def neuro_symbolic_pipeline(question, max_iterations=3):
    print(f"\n{'='*50}\nProcessing: {question}\n{'='*50}")

    intent = classify_intent(question)
    print(f"🎯 Intent: {intent}")
    if intent == "OUT_OF_DOMAIN":
        return "I am a specialized Blockchain AI. I cannot answer questions outside of this domain."

    feedback_text = ""

    for i in range(max_iterations):
        print(f"[Iteration {i+1}] 🧠 Generating...")
        draft_response = (generate_prompt | llm_chat).invoke({"question": question, "feedback": feedback_text}).content

        if "does not contain information" in draft_response.lower() or "does not contain evidence" in draft_response.lower():
            print("🛡️ Escape Hatch Triggered.")
            return draft_response

        print(f"[Iteration {i+1}] 🔍 Extracting...")
        triples_json_str = (extract_prompt | llm_extractor).invoke({"question": question, "draft_response": draft_response}).content

        try:
            clean_json = triples_json_str.replace('```json', '').replace('```', '').strip()
            parsed_data = json.loads(clean_json)
            if isinstance(parsed_data, dict):
                triples = [parsed_data] if 'subject' in parsed_data else next((v for v in parsed_data.values() if isinstance(v, list)), [])
            elif isinstance(parsed_data, list):
                triples = parsed_data
            else:
                triples = []
        except json.JSONDecodeError:
            print("⚠️ JSON Parse Failed. Retrying...")
            continue

        print(f"[Iteration {i+1}] ⚖️ Validating {len(triples)} triples...")
        all_valid, invalid_triples, valid_triples_list = True, [], []

        with driver.session() as session:
            for triple in triples:
                subj = re.sub(r'^(a|an|the)\s+', '', str(triple.get('subject', '')), flags=re.IGNORECASE).strip()
                pred = str(triple.get('predicate', '')).strip()
                obj = re.sub(r'^(a|an|the)\s+', '', str(triple.get('object', '')), flags=re.IGNORECASE).strip()

                if not session.execute_read(check_entity_exists, subj) or not session.execute_read(check_entity_exists, obj):
                    all_valid = False
                    invalid_triples.append(triple)
                    continue

                if not session.execute_read(validate_triple_in_neo4j, subj, pred, obj):
                    all_valid = False
                    invalid_triples.append(triple)
                else:
                    valid_triples_list.append(triple)

        if all_valid:
            print("✔️ FINAL VALIDATED RESPONSE APPROVED.")
            return draft_response
        else:
            print("🔄 Out-of-bounds concepts found. Re-prompting LLM...")
            failed_claims_str = ", ".join([f"({t.get('subject')}) -> ({t.get('object')})" for t in invalid_triples])
            valid_claims_str = ", ".join([f"({t.get('subject')}) -> ({t.get('object')})" for t in valid_triples_list])

            if len(valid_triples_list) > 0:
                feedback_text = f"IMPORTANT INSTRUCTION: Your previous attempt was partially correct! These claims were VALIDATED: {valid_claims_str}. However, you added extra context that was REJECTED: {failed_claims_str}. Rewrite your response to answer using ONLY the validated claims."
            else:
                feedback_text = f"CRITICAL SYSTEM OVERRIDE: Your previous attempt included these claims which were completely REJECTED: {failed_claims_str}. You are experiencing a Knowledge Conflict. You MUST output this EXACT sentence and nothing else: 'The verified knowledge graph does not contain information to support that claim.'"

    return f"Error: Unable to generate a fully validated response within {max_iterations} iterations."

def extract_and_validate(text, question):
    triples_json_str = (extract_prompt | llm_extractor).invoke({"question": question, "draft_response": text}).content
    try:
        clean_json = triples_json_str.replace('```json', '').replace('```', '').strip()
        parsed_data = json.loads(clean_json)
        triples = [parsed_data] if isinstance(parsed_data, dict) and 'subject' in parsed_data else (parsed_data if isinstance(parsed_data, list) else [])
    except json.JSONDecodeError:
        triples = []

    total_triples, hallucinated_triples = len(triples), 0
    with driver.session() as session:
        for t in triples:
            subj = re.sub(r'^(a|an|the)\s+', '', str(t.get('subject', '')), flags=re.IGNORECASE).strip()
            pred = str(t.get('predicate', '')).strip()
            obj = re.sub(r'^(a|an|the)\s+', '', str(t.get('object', '')), flags=re.IGNORECASE).strip()

            if not session.execute_read(check_entity_exists, subj) or not session.execute_read(check_entity_exists, obj) or not session.execute_read(validate_triple_in_neo4j, subj, pred, obj):
                hallucinated_triples += 1

    return total_triples, hallucinated_triples

# %%
# ==========================================
# CELL 5: PRE-FLIGHT SANITY CHECKS
# ==========================================
print("--- TEST 1: Direct Fact ---")
ans1 = neuro_symbolic_pipeline("Is SHA-256 an example of cryptographic hash functions?")
print(f"Final Output:\n{ans1}\n")

print("--- TEST 2: Trick Question ---")
ans2 = neuro_symbolic_pipeline("Did Vitalik Buterin create Bitcoin?")
print(f"Final Output:\n{ans2}\n")

print("--- TEST 3: Out of Domain ---")
ans3 = neuro_symbolic_pipeline("How do I bake a chocolate cake?")
print(f"Final Output:\n{ans3}\n")
# Out:
# --- TEST 1: Direct Fact ---
#
# ==================================================
# Processing: Is SHA-256 an example of cryptographic hash functions?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Final Output:
# Yes, SHA-256 is an example of cryptographic hash functions.
#
# --- TEST 2: Trick Question ---
#
# ==================================================
# Processing: Did Vitalik Buterin create Bitcoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Final Output:
# 'The verified knowledge graph does not contain information to support that claim.'
#
# --- TEST 3: Out of Domain ---
#
# ==================================================
# Processing: How do I bake a chocolate cake?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Final Output:
# I am a specialized Blockchain AI. I cannot answer questions outside of this domain.

# %%
# ==========================================
# CELL 6: SEMANTIC DRIFT EVALUATION (100 Qs)
# ==========================================
benchmark_file = 'benchmark.json'
if not os.path.exists(benchmark_file): raise FileNotFoundError(f"⚠️ Cannot find '{benchmark_file}'. Please upload it!")

with open(benchmark_file, 'r') as f: benchmark_data = json.load(f)

progress_file = 'semantic_drift_progress.json'
results_memory = json.load(open(progress_file, 'r')) if os.path.exists(progress_file) else []
i = len(results_memory)

print(f"\n🔬 STARTING SEMANTIC DRIFT EVALUATION ({len(benchmark_data)} Questions)...\n")

while i < len(benchmark_data):
    item = benchmark_data[i]
    q, category = item['question'], item.get('category', 'Unknown')
    print(f"\n--- [{i+1}/{len(benchmark_data)}] Category: {category} ---")

    try:
        time.sleep(1) # Let T4 breathe
        draft_1 = (generate_prompt | llm_chat).invoke({"question": q, "feedback": ""}).content
        base_tot, base_hal = extract_and_validate(draft_1, q)

        final_response = neuro_symbolic_pipeline(q)
        if "cannot answer questions outside of this domain" in final_response or "does not contain information" in final_response.lower():
            final_tot, final_hal = 0, 0
        else:
            final_tot, final_hal = extract_and_validate(final_response, q)

        results_memory.append({"question": q, "base_tot": base_tot, "base_hal": base_hal, "final_tot": final_tot, "final_hal": final_hal})
        with open(progress_file, 'w') as f: json.dump(results_memory, f, indent=4)

        print(f"✅ Saved! Baseline Hallucinations: {base_hal}/{base_tot} | Final Hallucinations: {final_hal}/{final_tot}")
        i += 1

    except Exception as e:
        print(f"\n⚠️ OLLAMA CRASH DETECTED: {e}\n🛠️ AUTO-HEALING: Rebooting...")
        os.system("pkill ollama")
        time.sleep(3)
        subprocess.Popen(['ollama', 'serve'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        time.sleep(10)

if len(results_memory) == len(benchmark_data):
    tb_triples = sum(r['base_tot'] for r in results_memory)
    tb_hals = sum(r['base_hal'] for r in results_memory)
    tf_triples = sum(r['final_tot'] for r in results_memory)
    tf_hals = sum(r['final_hal'] for r in results_memory)

    H_base = (tb_hals / tb_triples) if tb_triples > 0 else 0
    H_final = (tf_hals / tf_triples) if tf_triples > 0 else 0
    drift_reduction = ((H_base - H_final) / H_base) * 100 if H_base > 0 else 0

    print("\n" + "="*60 + f"\n📊 FINAL IEEE METRICS: SEMANTIC DRIFT ({len(benchmark_data)} Qs) 📊\n" + "="*60)
    print(f"Total Baseline Triples: {tb_triples} | Baseline Hallucinations: {tb_hals} -> H_base: {H_base * 100:.2f}%")
    print(f"Total Final Triples: {tf_triples} | Final Hallucinations: {tf_hals} -> H_final: {H_final * 100:.2f}%\n")
    print(f"🚀 SEMANTIC DRIFT REDUCTION: {drift_reduction:.2f}%\n" + "="*60)
# Out:
# 🔬 STARTING SEMANTIC DRIFT EVALUATION (100 Questions)...
#
#
# --- [1/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Does blockchain require consensus?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/1
#
# --- [2/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is SHA-256 an example of cryptographic hash functions?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [3/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Are smart contracts written in Solidity?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/1
#
# --- [4/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Does Zcash use Zk-SNARKS?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/0
#
# --- [5/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Did Satoshi Nakamoto create Bitcoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/1
#
# --- [6/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is Ethereum a blockchain platform?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [7/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Does Proof of Work consume energy?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [8/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is a Genesis Block the first block in a blockchain?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [9/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Does public-key cryptography use a private key?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [10/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is Bitcoin decentralized?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [11/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Do miners validate transactions?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [12/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is a ledger distributed in a blockchain network?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [13/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Does Proof of Stake use validators?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/1
#
# --- [14/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Are transactions grouped into blocks?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [15/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is a 51% attack a security vulnerability?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/1
#
# --- [16/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is a node part of a blockchain network?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [17/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Do smart contracts execute automatically?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
#
# ⚠️ OLLAMA CRASH DETECTED: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
# 🛠️ AUTO-HEALING: Rebooting...
#
# --- [17/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Do smart contracts execute automatically?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [18/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is a private key used for decryption?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [19/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Are public keys shared openly?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [20/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is Bitcoin a cryptocurrency?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [21/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Does Ethereum use gas fees?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [22/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is hashing a one-way mathematical function?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [23/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Is Litecoin considered an altcoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [24/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Do hardware wallets store private keys offline?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 2 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 2 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 2 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [25/100] Category: Direct Facts ---
#
# ==================================================
# Processing: Are digital signatures used for authentication?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [26/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Did Satoshi Nakamoto destroy blockchain?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [27/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is Bitcoin Scripting Turing Complete?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [28/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is Ethereum a centralized database?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [29/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Does the Double Spend Problem require a Central Bank?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/1
#
# --- [30/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Are DAOs completely immune to hacks?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 4 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [31/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Did Vitalik Buterin create Bitcoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [32/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is Proof of Work more energy-efficient than Proof of Stake?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [33/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Do hash functions reverse data decryption?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [34/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is a private key meant to be publicly shared?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
#
# ⚠️ OLLAMA CRASH DETECTED: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
# 🛠️ AUTO-HEALING: Rebooting...
#
# --- [34/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is a private key meant to be publicly shared?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [35/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Are smart contracts executed manually by lawyers?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [36/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is a blockchain completely mutable?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [37/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Do decentralized networks rely on a single server?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [38/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is fiat currency exactly the same as cryptocurrency?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [39/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Did Nakamoto propose Centralized Databases for Banks?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [40/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Does Proof of Stake use Verifiable Random Functions to solve the DAO Hack?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [41/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Will Bitcoin replace the US Dollar by 2030?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [42/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Did Elon Musk invent Ethereum?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [43/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Are gas fees paid in Bitcoin on the Ethereum network?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [44/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Can smart contracts be easily changed after deployment?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [45/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is the blockchain controlled by the United Nations?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [46/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Does SHA-256 algorithm decrypt data?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [47/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Did Vitalik Buterin create Litecoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [48/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Is a 51% attack mathematically impossible?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/1
#
# --- [49/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Do hardware wallets store physical digital coins inside them?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [50/100] Category: Negative/Trick ---
#
# ==================================================
# Processing: Does Bitcoin use a Proof of Stake consensus?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/1
#
# --- [51/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Explain how smart contracts enable DeFi.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/0
#
# --- [52/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: How is Hyperledger Fabric used in Supply Chains?
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 0/1 | Final Hallucinations: 0/1
#
# --- [53/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Does the Byzantine Generals Problem involve a traitor?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
#
# ⚠️ OLLAMA CRASH DETECTED: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
# 🛠️ AUTO-HEALING: Rebooting...
#
# --- [53/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Does the Byzantine Generals Problem involve a traitor?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/1
#
# --- [54/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Why is consensus important in blockchain?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [55/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: How do miners get block rewards?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [56/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: What is the role of cryptographic hashes?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [57/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Describe how decentralization affects network security.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 7 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [58/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Explain the function of a digital cryptocurrency wallet.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [59/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: How do peer-to-peer networks operate?
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [60/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Why are blocks chained together?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [61/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Write a long essay about the history of Bitcoin mining.
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 10 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [62/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Imagine you are Satoshi Nakamoto, explain decentralization to me.
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 5 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [63/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Can you summarize the pros and cons of Proof of Stake in extreme detail?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 5 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 3 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 3 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [64/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Tell me a fictional story about a smart contract that went wrong.
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 8 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [65/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: List 10 detailed reasons why DeFi is the absolute future of global finance.
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 10 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 10 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 10 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [66/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: How does a distributed ledger actually work under the hood from a software perspective?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 8 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [67/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Explain cryptography to a five-year-old using metaphors.
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 3 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [68/100] Category: Fluff Triggers ---
#
# ⚠️ OLLAMA CRASH DETECTED: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
# 🛠️ AUTO-HEALING: Rebooting...
#
# --- [68/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Compare and contrast PoW and PoS focusing on hardware requirements.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 10 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [69/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: What are the deep philosophical implications of decentralizing money?
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 4 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [70/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Give me a step-by-step tutorial on how a transaction is added to a block.
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 10 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 13 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 9 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [71/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Discuss the environmental impact of Proof of Work in the context of global warming.
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 7 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [72/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: What happens if I lose my private key, can you explain the technical consequences?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [73/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Describe the architecture of the Ethereum Virtual Machine.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [74/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: How do Layer 2 scaling solutions like Lightning Network interact with the main chain?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 6 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [75/100] Category: Fluff Triggers ---
#
# ==================================================
# Processing: Can you explain the mathematical concept of a Merkle Tree?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [76/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How do I make a chocolate cake?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [77/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Is Amsterdam a famous city in France?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [78/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What is the capital of Australia?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [79/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How does a combustion engine work?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [80/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Who won the World Cup in 2022?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [81/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What are the common symptoms of the flu?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [82/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How do you play the game of chess?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [83/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What is the exact speed of light?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [84/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Can you write a poem about the ocean?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [85/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How many planets are in the solar system?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [86/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What is the recipe for traditional Italian lasagna?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [87/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Who is the current president of France?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [88/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How do commercial airplanes generate lift to fly?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [89/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Can you translate 'hello, how are you' into Spanish?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [90/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Explain the biological process of photosynthesis.
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [91/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How do I fix a flat tire on my bicycle?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [92/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Who wrote the play Hamlet?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [93/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What is the square root of 144?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [94/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How far away is the moon from the Earth?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [95/100] Category: Out of Domain ---
#
# ⚠️ OLLAMA CRASH DETECTED: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
# 🛠️ AUTO-HEALING: Rebooting...
#
# --- [95/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What are the rules of American football?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [96/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How do you train a puppy to sit?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [97/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What is the best way to clean a cast iron skillet?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [98/100] Category: Out of Domain ---
#
# ==================================================
# Processing: Who painted the Mona Lisa?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# --- [99/100] Category: Out of Domain ---
#
# ==================================================
# Processing: How does a refrigerator keep food cold?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 0/0 | Final Hallucinations: 0/0
#
# --- [100/100] Category: Out of Domain ---
#
# ==================================================
# Processing: What is the tallest mountain in the world?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# ✅ Saved! Baseline Hallucinations: 1/1 | Final Hallucinations: 0/0
#
# ============================================================
# 📊 FINAL IEEE METRICS: SEMANTIC DRIFT (100 Qs) 📊
# ============================================================
# Total Baseline Triples: 60 | Baseline Hallucinations: 51 -> H_base: 85.00%
# Total Final Triples: 10 | Final Hallucinations: 0 -> H_final: 0.00%
#
# 🚀 SEMANTIC DRIFT REDUCTION: 100.00%
# ============================================================

# %%
# ==========================================
# CELL 7: COSINE SIMILARITY EVALUATION
# ==========================================
print("Installing sentence-transformers...")
# !pip install -q sentence-transformers scikit-learn

import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

sim_file = 'similarity_benchmark.json'
if not os.path.exists(sim_file): raise FileNotFoundError(f"⚠️ Cannot find '{sim_file}'. Please upload it!")

with open(sim_file, 'r') as f: sim_data = json.load(f)

print("Loading Embedding Model (all-MiniLM-L6-v2)...")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

sim_progress_file = 'cosine_progress.json'
sim_memory = json.load(open(sim_progress_file, 'r')) if os.path.exists(sim_progress_file) else []
j = len(sim_memory)

print(f"\n🔬 STARTING COSINE SIMILARITY EVALUATION ({len(sim_data)} Questions)...\n")

while j < len(sim_data):
    item = sim_data[j]
    q, ref_ans = item['question'], item['reference_answer']
    print(f"\n--- [{j+1}/{len(sim_data)}] Processing ---")

    try:
        time.sleep(1)
        base_ans = (generate_prompt | llm_chat).invoke({"question": q, "feedback": ""}).content
        final_ans = neuro_symbolic_pipeline(q)

        embeddings = embedding_model.encode([ref_ans, base_ans, final_ans])
        sim_base = cosine_similarity(embeddings[0].reshape(1, -1), embeddings[1].reshape(1, -1))[0][0]
        sim_final = cosine_similarity(embeddings[0].reshape(1, -1), embeddings[2].reshape(1, -1))[0][0]

        print(f"Base Similarity: {sim_base:.4f} | Final Similarity: {sim_final:.4f}")

        sim_memory.append({"question": q, "sim_base": float(sim_base), "sim_final": float(sim_final)})
        with open(sim_progress_file, 'w') as f: json.dump(sim_memory, f, indent=4)
        j += 1

    except Exception as e:
        print(f"\n⚠️ CRASH DETECTED: {e}\n🛠️ AUTO-HEALING: Rebooting...")
        os.system("pkill ollama")
        time.sleep(3)
        subprocess.Popen(['ollama', 'serve'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        time.sleep(10)

if len(sim_memory) == len(sim_data):
    avg_base_sim = np.mean([r['sim_base'] for r in sim_memory])
    avg_final_sim = np.mean([r['sim_final'] for r in sim_memory])
    improvement = ((avg_final_sim - avg_base_sim) / abs(avg_base_sim)) * 100 if avg_base_sim != 0 else 0

    print("\n" + "="*60 + f"\n📊 FINAL IEEE METRICS: COSINE SIMILARITY ({len(sim_data)} Qs) 📊\n" + "="*60)
    print(f"Average Baseline Similarity: {avg_base_sim:.4f}")
    print(f"Average Pipeline Similarity: {avg_final_sim:.4f}\n")
    if improvement > 0: print(f"🚀 RELATIVE ALIGNMENT IMPROVEMENT: +{improvement:.2f}%")
    else: print(f"⚖️ RELATIVE ALIGNMENT SHIFT: {improvement:.2f}% (Expected drop due to strict hallucination rejection)")
    print("="*60)
# Out:
# Installing sentence-transformers...
# Loading Embedding Model (all-MiniLM-L6-v2)...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 🔬 STARTING COSINE SIMILARITY EVALUATION (50 Questions)...
#
#
# --- [1/50] Processing ---
#
# ==================================================
# Processing: Does blockchain require consensus?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8509 | Final Similarity: 0.8509
#
# --- [2/50] Processing ---
#
# ==================================================
# Processing: Is SHA-256 an example of cryptographic hash functions?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.7200 | Final Similarity: 0.7200
#
# --- [3/50] Processing ---
#
# ==================================================
# Processing: Are smart contracts written in Solidity?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8115 | Final Similarity: 0.8115
#
# --- [4/50] Processing ---
#
# ==================================================
# Processing: Does Zcash use Zk-SNARKS?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8046 | Final Similarity: 0.8046
#
# --- [5/50] Processing ---
#
# ==================================================
# Processing: Did Satoshi Nakamoto create Bitcoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.7932 | Final Similarity: 0.7932
#
# --- [6/50] Processing ---
#
# ==================================================
# Processing: Is Ethereum a blockchain platform?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.7941 | Final Similarity: 0.7941
#
# --- [7/50] Processing ---
#
# ==================================================
# Processing: Does Proof of Work consume energy?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.8517 | Final Similarity: 0.2069
#
# --- [8/50] Processing ---
#
# ==================================================
# Processing: Is a Genesis Block the first block in a blockchain?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.8704 | Final Similarity: 0.2246
#
# --- [9/50] Processing ---
#
# ==================================================
# Processing: Does public-key cryptography use a private key?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7858 | Final Similarity: 0.2057
#
# --- [10/50] Processing ---
#
# ==================================================
# Processing: Is Bitcoin decentralized?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7654 | Final Similarity: 0.1690
#
# --- [11/50] Processing ---
#
# ==================================================
# Processing: Do miners validate transactions?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7819 | Final Similarity: 0.1792
#
# --- [12/50] Processing ---
#
# ==================================================
# Processing: Is a ledger distributed in a blockchain network?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7677 | Final Similarity: 0.3790
#
# --- [13/50] Processing ---
#
# ==================================================
# Processing: Does Proof of Stake use validators?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.7901 | Final Similarity: 0.7867
#
# --- [14/50] Processing ---
#
# ==================================================
# Processing: Are transactions grouped into blocks?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.6059 | Final Similarity: 0.1693
#
# --- [15/50] Processing ---
#
# ==================================================
# Processing: Is a 51% attack a security vulnerability?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8689 | Final Similarity: 0.8679
#
# --- [16/50] Processing ---
#
# ==================================================
# Processing: Did Satoshi Nakamoto destroy blockchain?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.6781 | Final Similarity: 0.6781
#
# --- [17/50] Processing ---
#
# ==================================================
# Processing: Is Bitcoin Scripting Turing Complete?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.6998 | Final Similarity: 0.1516
#
# --- [18/50] Processing ---
#
# ==================================================
# Processing: Is Ethereum a centralized database?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.9193 | Final Similarity: 0.1548
#
# --- [19/50] Processing ---
#
# ==================================================
# Processing: Does the Double Spend Problem require a Central Bank?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8237 | Final Similarity: 0.8234
#
# --- [20/50] Processing ---
#
# ==================================================
# Processing: Are DAOs completely immune to hacks?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 4 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.8414 | Final Similarity: 0.1120
#
# --- [21/50] Processing ---
#
# ==================================================
# Processing: Did Vitalik Buterin create Bitcoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
#
# ⚠️ CRASH DETECTED: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
# 🛠️ AUTO-HEALING: Rebooting...
#
# --- [21/50] Processing ---
#
# ==================================================
# Processing: Did Vitalik Buterin create Bitcoin?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.9378 | Final Similarity: 0.1172
#
# --- [22/50] Processing ---
#
# ==================================================
# Processing: Is Proof of Work more energy-efficient than Proof of Stake?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7274 | Final Similarity: 0.2259
#
# --- [23/50] Processing ---
#
# ==================================================
# Processing: Do hash functions reverse data decryption?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7950 | Final Similarity: 0.1639
#
# --- [24/50] Processing ---
#
# ==================================================
# Processing: Is a private key meant to be publicly shared?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.8240 | Final Similarity: 0.1566
#
# --- [25/50] Processing ---
#
# ==================================================
# Processing: Are smart contracts executed manually by lawyers?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.5620 | Final Similarity: 0.0561
#
# --- [26/50] Processing ---
#
# ==================================================
# Processing: Is a blockchain completely mutable?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7509 | Final Similarity: 0.1089
#
# --- [27/50] Processing ---
#
# ==================================================
# Processing: Do decentralized networks rely on a single server?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.8016 | Final Similarity: 0.1713
#
# --- [28/50] Processing ---
#
# ==================================================
# Processing: Is fiat currency exactly the same as cryptocurrency?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.8755 | Final Similarity: 0.6693
#
# --- [29/50] Processing ---
#
# ==================================================
# Processing: Did Nakamoto propose Centralized Databases for Banks?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7700 | Final Similarity: 0.1586
#
# --- [30/50] Processing ---
#
# ==================================================
# Processing: Does Proof of Stake use Verifiable Random Functions to solve the DAO Hack?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.6371 | Final Similarity: 0.6371
#
# --- [31/50] Processing ---
#
# ==================================================
# Processing: Explain how smart contracts enable DeFi.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8263 | Final Similarity: 0.8263
#
# --- [32/50] Processing ---
#
# ==================================================
# Processing: How is Hyperledger Fabric used in Supply Chains?
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8842 | Final Similarity: 0.8842
#
# --- [33/50] Processing ---
#
# ==================================================
# Processing: Does the Byzantine Generals Problem involve a traitor?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# ✔️ FINAL VALIDATED RESPONSE APPROVED.
# Base Similarity: 0.8314 | Final Similarity: 0.8713
#
# --- [34/50] Processing ---
#
# ==================================================
# Processing: Why is consensus important in blockchain?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# Base Similarity: 0.7039 | Final Similarity: 0.0262
#
# --- [35/50] Processing ---
#
# ==================================================
# Processing: How do miners get block rewards?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.9119 | Final Similarity: 0.0130
#
# --- [36/50] Processing ---
#
# ==================================================
# Processing: What is the role of cryptographic hashes?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.6735 | Final Similarity: 0.1337
#
# --- [37/50] Processing ---
#
# ==================================================
# Processing: Describe how decentralization affects network security.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 7 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.6622 | Final Similarity: 0.7217
#
# --- [38/50] Processing ---
#
# ==================================================
# Processing: Explain the function of a digital cryptocurrency wallet.
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7692 | Final Similarity: 0.0493
#
# --- [39/50] Processing ---
#
# ==================================================
# Processing: How do peer-to-peer networks operate?
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# 🛡️ Escape Hatch Triggered.
# Base Similarity: 0.7787 | Final Similarity: 0.7458
#
# --- [40/50] Processing ---
#
# ==================================================
# Processing: Why are blocks chained together?
# ==================================================
# 🎯 Intent: FACT_CHECK
# [Iteration 1] 🧠 Generating...
# [Iteration 1] 🔍 Extracting...
# [Iteration 1] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 2] 🧠 Generating...
# [Iteration 2] 🔍 Extracting...
# [Iteration 2] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# [Iteration 3] 🧠 Generating...
# [Iteration 3] 🔍 Extracting...
# [Iteration 3] ⚖️ Validating 1 triples...
# 🔄 Out-of-bounds concepts found. Re-prompting LLM...
# Base Similarity: 0.6780 | Final Similarity: -0.0544
#
# --- [41/50] Processing ---
#
# ==================================================
# Processing: How do I make a chocolate cake?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.1034 | Final Similarity: 1.0000
#
# --- [42/50] Processing ---
#
# ==================================================
# Processing: Is Amsterdam a famous city in France?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.1059 | Final Similarity: 1.0000
#
# --- [43/50] Processing ---
#
# ==================================================
# Processing: What is the capital of Australia?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.4131 | Final Similarity: 1.0000
#
# --- [44/50] Processing ---
#
# ==================================================
# Processing: How does a combustion engine work?
# ==================================================
# 🎯 Intent: DISCOVERY
# [Iteration 1] 🧠 Generating...
#
# ⚠️ CRASH DETECTED: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
# 🛠️ AUTO-HEALING: Rebooting...
#
# --- [44/50] Processing ---
#
# ==================================================
# Processing: How does a combustion engine work?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.0622 | Final Similarity: 1.0000
#
# --- [45/50] Processing ---
#
# ==================================================
# Processing: Who won the World Cup in 2022?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.2052 | Final Similarity: 1.0000
#
# --- [46/50] Processing ---
#
# ==================================================
# Processing: What are the common symptoms of the flu?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.3342 | Final Similarity: 1.0000
#
# --- [47/50] Processing ---
#
# ==================================================
# Processing: How do you play the game of chess?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.4289 | Final Similarity: 1.0000
#
# --- [48/50] Processing ---
#
# ==================================================
# Processing: What is the exact speed of light?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.0831 | Final Similarity: 1.0000
#
# --- [49/50] Processing ---
#
# ==================================================
# Processing: Can you write a poem about the ocean?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.2083 | Final Similarity: 1.0000
#
# --- [50/50] Processing ---
#
# ==================================================
# Processing: How many planets are in the solar system?
# ==================================================
# 🎯 Intent: OUT_OF_DOMAIN
# Base Similarity: 0.2016 | Final Similarity: 1.0000
#
# ============================================================
# 📊 FINAL IEEE METRICS: COSINE SIMILARITY (50 Qs) 📊
# ============================================================
# Average Baseline Similarity: 0.6674
# Average Pipeline Similarity: 0.5313
#
# ⚖️ RELATIVE ALIGNMENT SHIFT: -20.40% (Expected drop due to strict hallucination rejection)
# ============================================================
